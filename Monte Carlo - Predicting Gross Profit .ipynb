# %% [markdown]
# GOAL: predict the firm's future gross profit
#
# We need:
# 1. Expected Revenue
# 2. Cost of Good Sold (COGS)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rev_m = 170    # in millions
rev_std = 20   # revenue standard deviation
iterations = 1000   # number of simulated observations

# %%
rev = np.random.normal(rev_m, rev_std, iterations)
rev
# Out:
# array([190.37070009, 183.12675343, 157.67266148, 162.54204695,
#        189.14749172, 180.59093555, 170.28835244, 161.3748537 ,
#        150.38516885, 171.51118772, 167.48384328, 205.148465  ,
#        184.56895907, 142.182102  , 168.24290332, 175.05866414,
#        162.58989874, 160.85011616, 201.93532451, 184.7474719 ,
#        171.32382707, 169.04184468, 158.50617499, 163.86512571,
#        187.74016327, 125.16947101, 160.69206146, 206.68386756,
#        200.13434031, 183.84875711, 177.84949901, 189.74406785,
#        181.47453078, 166.37990347, 171.15736092, 206.85143723,
#        198.45297474, 182.28422634, 163.20430527, 174.19031686,
#        154.71917261, 147.37983312, 162.57861619, 190.40484645,
#        164.50223758, 170.90928353, 175.95445692, 175.01336297,
#        199.17306145, 147.12292083, 166.58481116, 168.62612985,
#        149.77810918, 163.7694548 , 192.33106659, 161.1759533 ,
#        175.13788399, 155.98243435, 185.46436273, 182.78656863,
# ...

# %%
plt.figure(figsize=(15,6))
plt.plot(rev)
plt.show()

# %%
COGS = - (rev * np.random.normal(0.6,0.1))
    # negative because COGS is money spent
        # COGS ~ 60% of the revenues
        # the distribution deviates 10% regarding the mean of COGS
plt.figure(figsize=(15,6))
plt.plot(COGS)
plt.show()

# %%
COGS.mean()
# Out:
# -141.61647796105217

# %%
COGS.std()
# Out:
# 16.974793120610876

# %%
gross_profit = rev + COGS
gross_profit

plt.figure(figsize=(15,6))
plt.plot(gross_profit)
plt.show()

# %%
max(gross_profit)
# Out:
# 37.688045773064545

# %%
min(gross_profit)
# Out:
# 19.02496709480812

# %%
gross_profit.mean()
# Out:
# 28.257727223078078

# %%
gross_profit.std()
# Out:
# 3.3870993021188154

# %%
plt.figure(figsize=(10,6))
plt.hist(gross_profit, bins = [40,50,60,70,80,90,100,110,120])
plt.show()

# making a histogram
# bins are the chunks in which the data in the plot will be divided

# %%
plt.figure(figsize=(10,6))
plt.hist(gross_profit, bins = 20)
plt.show()
